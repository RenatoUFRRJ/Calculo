# %%
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
x = []
y = []
for i in np.arange(-100,101,0.05):
    x.append(i)

for i in x:
    y.append(2*i*math.cos(i) + math.sin(i) - (i**2)*math.sin(i))
    
  
plt.figure(figsize=(10,5))
plt.plot(x, y,linestyle = '-',color='blue',linewidth=1)


  
plt.xticks(())
plt.yticks(())

plt.show()

# %%
# método newton nao deu certo

def f(x):
    return 2*x*math.cos(x) + math.sin(x) - ((x**2 )*math.sin(x))
def df(x):
    return ( 2 * math.cos(x)  - 2 * x*math.sin(x)  )    +   math.cos(x)   -     (  2*x*math.sin(x) +  x*2*math.cos(x)  )
    

entradas = []
saidas = []


r = 10 # raiz inicial


for i in np.arange(0,20,0.5):
    entradas.append(i)

for i in range(len(entradas)):
    saidas.append(f(entradas[i]))

e = 0.05
for _ in range(10000):
    
    a = r
    r = r - f(r)/(df(r) + e)
    #print(r,f(r), df(r0))
    #if abs(a - r) < 0.00001:
        #break

# %%
r
# Out:
# -1.306542374188806

# %%
z =[]
for _ in range( len(entradas)):
    z.append(0)
plt.figure(figsize=(20,5))
plt.scatter(entradas,saidas,color='green')
#plt.xlim(0,5)
#plt.plot(entradas,saidas,linestyle = '-',color='blue',linewidth=1)
plt.plot(entradas,z,linestyle = '--',color='red',linewidth=1)

plt.show()

# %%
#metodo bissecçao deu certo

def f(x):
    return 2*x*math.cos(x) + math.sin(x) - ((x**2 )*math.sin(x))


def verificador(a,b):
    if f(a) * f(b) > 0:
        return 1
    
    else:
        return 0

entradas = []
saidas = []
raizes = []
r = 0

tam = 50
intervalo = [-tam, 1 - tam] #dividir a funcao em blocos de 1 em 1

for i in np.arange(-tam,tam,0.5): #criar valores x  da funcao entre 0 e 1000 
    entradas.append(i)


for i in range(len(entradas)): # gera os valores de y com base nos de x
    saidas.append(f(entradas[i]))

for i in range(2*tam) :# algoritmo do metodo da bissecçao
    
    a = intervalo[0]
    b = intervalo[1]
    aux = r
    for _ in range(100):
    
        r = p_medio = (intervalo[0] + intervalo[1]) / 2
                      
        if verificador(intervalo[0] , p_medio) == 1:
            intervalo[0] = p_medio
        else: 
            intervalo[1] = p_medio
        
    
        if abs(r - aux) < 0.0000001:
            break
    
        aux = r

    if abs(f(r) - 0) <= 0.01:
        raizes.append(r)

    
    intervalo[0] = a + 1
    intervalo[1] = b + 1
    
    if len(raizes) >= 50:
        break

# %%
#os valores das raizes a 1 e 2 estao repetidas

zeros = []

for i in raizes:
    zeros.append(f(i))

for i in range(len(zeros)):
    
    if zeros[i] < 0.00001:
        zeros[i] = 0

# %%
z =[] #sera o eixo x
for _ in range( len(entradas)):
    z.append(0)
plt.figure(figsize=(20,15))
#plt.scatter(entradas,saidas,color='green')
plt.scatter(raizes,zeros,color='black')
#plt.xlim(0,60)
plt.plot(entradas,saidas,linestyle = '--',color='blue',linewidth=1)
plt.plot(entradas,z,linestyle = '-',color='red',linewidth=1)

plt.show()

# %%
x = 1.36 # subsititua os valores do vetor aqui para ver os resultados

#2*x*math.cos(x) + math.sin(x) - ((x**2 )*math.sin(x))

# %%
f(x)
# Out:
# -0.26166459500438477
